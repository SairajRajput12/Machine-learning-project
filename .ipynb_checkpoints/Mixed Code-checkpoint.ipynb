# %% [markdown]
# # First Getting the face recognition Code

# %% [markdown]
# ### A. Loading the Model of face recognition

# %%
import cv2
import numpy as np
import pickle
import keras

mp = keras.models.load_model("Models/FaceRecognitionModel.keras")
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read("Models/ModelToRecogniseUnrecogniseFace.yml")

# Load the face classifier
face_classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# Load the face map for label mapping
with open("ResultsMap.pkl", 'rb') as fileReadStream:
    ResultMap = pickle.load(fileReadStream)

print(ResultMap)
# Initialize the webcam
webcam = cv2.VideoCapture("sample_video1.mp4")

# Function to recognize faces
def recognize_faces(frame):
    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    name = ''
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_roi = frame[y:y+h, x:x+w]
        face_roi1 = gray[y:y+h, x:x+w]
        
        label_id, confidence = recognizer.predict(face_roi1)

        # Resize the face ROI to match the input size of the model
        resized_face = cv2.resize(face_roi, (64, 64))

        # Preprocess the face (normalize pixel values)
        normalized_face = resized_face / 255.0

        # Reshape the face for the model input (add batch dimension)
        reshaped_face = np.expand_dims(normalized_face, axis=0)

        # Perform prediction using the model
        prediction = mp.predict(reshaped_face)
        predicted_label = ResultMap[np.argmax(prediction)]
        print('confidence',prediction[0][np.argmax(prediction)])
        print(prediction)
        # print(predicted_label)
        print(np.max(prediction))
        name = predicted_label
        pre = np.max(prediction)
        print(confidence)
        if confidence > 100.07375104700013: 
            cv2.putText(frame, 'Unknown', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2) 
            name = 'Unknown'
        else:
            cv2.putText(frame, predicted_label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)


        # Draw the bounding box and label on the frame
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        

    return frame , name

# Main loop to capture frames from the webcam
while True:
    # Read a frame from the webcam
    ret, frame = webcam.read()
    if not ret:
        break

    # Perform face recognition on the frame
    frame , name = recognize_faces(frame)
    print(name)
    # Display the frame
    cv2.imshow('Face Recognition', frame)

    # Check for 'q' key to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
webcam.release()
cv2.destroyAllWindows()
# Out:
# {0: 'Pushkar', 1: 'Sairaj', 2: 'Tushar'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# confidence 0.34346375
# [[0.315617   0.34346375 0.34091926]]
# 0.34346375
# 29.471456248876287
# Sairaj
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# confidence 0.35209048
# [[0.32219616 0.35209048 0.32571328]]
# 0.35209048
# 37.2602401099915
# Sairaj
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# confidence 0.3565634
# [[0.31499267 0.3565634  0.32844394]]
# 0.3565634
# 86.57282547041586
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.3601562
# [[0.31297693 0.3601562  0.32686684]]
# 0.3601562
# 84.98550713189086
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.35973904
# [[0.31213808 0.35973904 0.32812288]]
# 0.35973904
# 82.6487274019187
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.3605732
# [[0.3121891 0.3605732 0.3272377]]
# 0.3605732
# 73.98890580909456
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.36456034
# [[0.31369796 0.36456034 0.32174167]]
# 0.36456034
# 97.29312473732182
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# confidence 0.36529616
# [[0.31283712 0.36529616 0.3218668 ]]
# 0.36529616
# 86.23278872422759
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# confidence 0.36509845
# [[0.31316477 0.36509845 0.32173678]]
# 0.36509845
# 100.49684763850841
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.3665928
# [[0.312926   0.3665928  0.32048124]]
# 0.3665928
# 98.75629369064028
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.3657932
# [[0.3144941  0.3657932  0.31971267]]
# 0.3657932
# 101.18793308286274
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# confidence 0.36456758
# [[0.3120373  0.36456758 0.3233952 ]]
# 0.36456758
# 109.16585586663575
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.36620128
# [[0.31234834 0.36620128 0.32145032]]
# 0.36620128
# 91.95430872148
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# confidence 0.3625095
# [[0.31282672 0.3625095  0.32466376]]
# 0.3625095
# 91.75619012823283
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.359993
# [[0.3110098  0.359993   0.32899722]]
# 0.359993
# 107.56239558594285
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.36156484
# [[0.3127201  0.36156484 0.3257151 ]]
# 0.36156484
# 90.94623397751883
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# confidence 0.3592807
# [[0.31240356 0.3592807  0.3283158 ]]
# 0.3592807
# 104.37648076532058
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# confidence 0.36055797
# [[0.3128343  0.36055797 0.32660773]]
# 0.36055797
# 93.14392707682221
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.3589831
# [[0.3126352 0.3589831 0.3283817]]
# 0.3589831
# 101.79584087427276
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# confidence 0.35710326
# [[0.31362844 0.35710326 0.32926828]]
# 0.35710326
# 97.74558413962421
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# confidence 0.35992223
# [[0.31190187 0.35992223 0.32817593]]
# 0.35992223
# 99.53016281041339
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.35959685
# [[0.3128832  0.35959685 0.32751995]]
# 0.35959685
# 100.25827174779336
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.3636713
# [[0.31210405 0.3636713  0.32422462]]
# 0.3636713
# 90.04835864464177
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.36439124
# [[0.31407636 0.36439124 0.32153234]]
# 0.36439124
# 92.69878556486265
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# confidence 0.36370668
# [[0.31718528 0.36370668 0.319108  ]]
# 0.36370668
# 95.82960530350528
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.3613218
# [[0.32045528 0.3613218  0.3182229 ]]
# 0.3613218
# 95.63120615320602
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# confidence 0.35814115
# [[0.32357532 0.35814115 0.3182835 ]]
# 0.35814115
# 95.84274838708889
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.35921222
# [[0.31935686 0.35921222 0.321431  ]]
# 0.35921222
# 96.41284962029074
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# confidence 0.3581535
# [[0.31803995 0.3581535  0.32380652]]
# 0.3581535
# 96.12739822815072
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# confidence 0.35658652
# [[0.31783473 0.35658652 0.32557878]]
# 0.35658652
# 93.55557646312053
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# confidence 0.35658824
# [[0.3173205  0.35658824 0.3260913 ]]
# 0.35658824
# 95.35011183885624
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.35516253
# [[0.32039037 0.35516253 0.3244471 ]]
# 0.35516253
# 88.77847383693585
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.3549695
# [[0.32035667 0.3549695  0.3246738 ]]
# 0.3549695
# 98.69021298686175
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.35268962
# [[0.32219893 0.35268962 0.32511145]]
# 0.35268962
# 100.23029153514877
# Unknown
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# confidence 0.3527983
# [[0.3218457  0.3527983  0.32535604]]
# 0.3527983
# 95.96120879362883
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.35152304
# [[0.32205954 0.35152304 0.32641742]]
# 0.35152304
# 95.30472018130195
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# confidence 0.35083213
# [[0.32274845 0.35083213 0.3264195 ]]
# 0.35083213
# 85.41945749602255
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.34965417
# [[0.32271656 0.34965417 0.32762927]]
# 0.34965417
# 97.05798936358723
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.3500275
# [[0.32208455 0.3500275  0.3278879 ]]
# 0.3500275
# 95.20364198397921
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.34898666
# [[0.3224934  0.34898666 0.32851994]]
# 0.34898666
# 87.77002375116446
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# confidence 0.34936646
# [[0.32216114 0.34936646 0.32847238]]
# 0.34936646
# 94.06489403997269
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# confidence 0.34891066
# [[0.3220227  0.34891066 0.32906663]]
# 0.34891066
# 95.07706598199823
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# confidence 0.34739915
# [[0.3235778  0.34739915 0.32902312]]
# 0.34739915
# 83.30976133044975
# Sairaj
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# confidence 0.34135577
# [[0.32406202 0.3345822  0.34135577]]
# 0.34135577
# 76.06528616068445
# Tushar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.33859223
# [[0.32497665 0.33643112 0.33859223]]
# 0.33859223
# 78.52944333331031
# Tushar
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.3456814
# [[0.3212316 0.333087  0.3456814]]
# 0.3456814
# 79.42668222445074
# Tushar
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# confidence 0.34344932
# [[0.32404187 0.33250886 0.34344932]]
# 0.34344932
# 72.41864835335052
# Tushar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# confidence 0.34375346
# [[0.31979185 0.33645466 0.34375346]]
# 0.34375346
# 74.77855729918286
# Tushar
#
#
#
#
#
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# confidence 0.3474491
# [[0.32183293 0.3474491  0.33071798]]
# 0.3474491
# 90.17420310542242
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# confidence 0.35097283
# [[0.32042164 0.35097283 0.32860553]]
# 0.35097283
# 99.9085682362425
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.35254493
# [[0.31991678 0.35254493 0.32753825]]
# 0.35254493
# 94.93835807931694
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.3536748
# [[0.31931084 0.3536748  0.32701433]]
# 0.3536748
# 92.49856344485192
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# confidence 0.3539139
# [[0.31895527 0.3539139  0.32713088]]
# 0.3539139
# 88.98669644833795
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.3544671
# [[0.31814757 0.3544671  0.32738528]]
# 0.3544671
# 94.35245156617245
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# confidence 0.3582276
# [[0.31628174 0.3582276  0.32549068]]
# 0.3582276
# 90.14589705561943
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# confidence 0.3597013
# [[0.31637514 0.3597013  0.3239235 ]]
# 0.3597013
# 93.64411442761465
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.36019725
# [[0.31469324 0.36019725 0.3251095 ]]
# 0.36019725
# 97.75489235785138
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.36146587
# [[0.31407452 0.36146587 0.3244596 ]]
# 0.36146587
# 87.4535431378766
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.36156216
# [[0.3134877  0.36156216 0.3249501 ]]
# 0.36156216
# 95.83976624227007
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# confidence 0.36166903
# [[0.31468087 0.36166903 0.32365015]]
# 0.36166903
# 85.50459591180001
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# confidence 0.3607534
# [[0.31251258 0.3607534  0.32673407]]
# 0.3607534
# 98.26212607946513
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# confidence 0.36063334
# [[0.31335804 0.36063334 0.3260086 ]]
# 0.36063334
# 97.40608057368813
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.36020935
# [[0.3141462  0.36020935 0.32564443]]
# 0.36020935
# 83.61720825604453
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# confidence 0.35939205
# [[0.31462497 0.35939205 0.32598296]]
# 0.35939205
# 83.15567333658119
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.35910237
# [[0.31497946 0.35910237 0.3259182 ]]
# 0.35910237
# 85.94440211711026
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.35881194
# [[0.3148525  0.35881194 0.3263355 ]]
# 0.35881194
# 84.57913991676634
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.35889205
# [[0.31530178 0.35889205 0.3258061 ]]
# 0.35889205
# 83.62142322829402
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.35793355
# [[0.31537318 0.35793355 0.3266933 ]]
# 0.35793355
# 84.55515091654517
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.3584106
# [[0.31488144 0.3584106  0.32670796]]
# 0.3584106
# 84.1261793426887
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# confidence 0.35754567
# [[0.31551102 0.35754567 0.32694325]]
# 0.35754567
# 86.99168699493708
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# confidence 0.35799724
# [[0.31490415 0.35799724 0.3270986 ]]
# 0.35799724
# 86.40448941310662
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.3581121
# [[0.31575298 0.3581121  0.32613492]]
# 0.3581121
# 86.19619834777129
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.35795408
# [[0.31523278 0.35795408 0.32681316]]
# 0.35795408
# 86.77483894117539
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# confidence 0.35902643
# [[0.31444493 0.35902643 0.32652867]]
# 0.35902643
# 85.86030424293351
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.3580308
# [[0.31525642 0.3580308  0.32671273]]
# 0.3580308
# 85.57912532685344
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.3581966
# [[0.3147532 0.3581966 0.3270502]]
# 0.3581966
# 84.95363726697394
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# confidence 0.35820365
# [[0.31504372 0.35820365 0.3267526 ]]
# 0.35820365
# 86.44086314091841
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.3582376
# [[0.3152688  0.3582376  0.32649362]]
# 0.3582376
# 86.49310239557646
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# confidence 0.3582725
# [[0.31520155 0.3582725  0.32652596]]
# 0.3582725
# 87.52802574492509
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# confidence 0.35804275
# [[0.31594494 0.35804275 0.32601225]]
# 0.35804275
# 85.00051044709923
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# confidence 0.35886455
# [[0.31596392 0.35886455 0.3251715 ]]
# 0.35886455
# 86.94290351636974
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# confidence 0.35907328
# [[0.31543446 0.35907328 0.32549235]]
# 0.35907328
# 88.13305446687993
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.3589533
# [[0.31469172 0.3589533  0.32635498]]
# 0.3589533
# 87.03233542232691
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# confidence 0.35843188
# [[0.31547394 0.35843188 0.32609415]]
# 0.35843188
# 86.02060815811481
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# confidence 0.35862994
# [[0.31403226 0.35862994 0.3273379 ]]
# 0.35862994
# 88.36499676906415
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# confidence 0.35825568
# [[0.31462485 0.35825568 0.3271194 ]]
# 0.35825568
# 87.49945500761874
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# confidence 0.35853443
# [[0.315593   0.35853443 0.3258725 ]]
# 0.35853443
# 89.16192702887876
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.35830066
# [[0.31528667 0.35830066 0.32641274]]
# 0.35830066
# 87.61861401680235
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.3586254
# [[0.3157001 0.3586254 0.3256744]]
# 0.3586254
# 91.4190811889487
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# confidence 0.35897055
# [[0.3161002  0.35897055 0.32492915]]
# 0.35897055
# 90.57610202570363
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# confidence 0.3584465
# [[0.3149317  0.3584465  0.32662186]]
# 0.3584465
# 91.49868125616955
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# confidence 0.35791504
# [[0.31651378 0.35791504 0.32557115]]
# 0.35791504
# 88.99681248986728
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.3583767
# [[0.31530675 0.3583767  0.3263166 ]]
# 0.3583767
# 93.13195180550622
# Sairaj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# confidence 0.35792783
# [[0.31742623 0.35792783 0.3246459 ]]
# 0.35792783
# 91.87211117898069
# Sairaj

# %% [markdown]
# ## B. Loading the model of the action recongition

# %%
import keras
from keras import layers, Sequential
from keras.models import load_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import cv2

import mediapipe as mp
import glob
import pandas as pd
import numpy as np
import math
import os 


# ap = argparse.ArgumentParser()
# ap.add_argument("-m", "--model", type=str, required=True,
#                 help="path to saved .h5 model, eg: dir/model.h5")
# ap.add_argument("-c", "--conf", type=float, required=True,
#                 help="min prediction conf to detect pose class (0<conf<1)")
# ap.add_argument("-i", "--source", type=str, required=True,
#                 help="path to sample image")
# ap.add_argument("--save", action='store_true',
#                 help="Save video")

# args = vars(ap.parse_args())
source = "sample_video1.mp4"
path_saved_model = "Models/Action Recognition/model.keras"
threshold = 0.2
save = "Output"
print('Hello')
##############
torso_size_multiplier = 2.5
n_landmarks = 33
n_dimensions = 3
landmark_names = [
    'nose',
    'left_eye_inner', 'left_eye', 'left_eye_outer',
    'right_eye_inner', 'right_eye', 'right_eye_outer',
    'left_ear', 'right_ear',
    'mouth_left', 'mouth_right',
    'left_shoulder', 'right_shoulder',
    'left_elbow', 'right_elbow',
    'left_wrist', 'right_wrist',
    'left_pinky_1', 'right_pinky_1',
    'left_index_1', 'right_index_1',
    'left_thumb_2', 'right_thumb_2',
    'left_hip', 'right_hip',
    'left_knee', 'right_knee',
    'left_ankle', 'right_ankle',
    'left_heel', 'right_heel',
    'left_foot_index', 'right_foot_index',
]
class_names = [
    'Running','Standing','Walking','Waving'
]
##############

mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

col_names = []
for i in range(n_landmarks):
    name = mp_pose.PoseLandmark(i).name
    name_x = name + '_X'
    name_y = name + '_Y'
    name_z = name + '_Z'
    name_v = name + '_V'
    col_names.append(name_x)
    col_names.append(name_y)
    col_names.append(name_z)
    col_names.append(name_v)

# Load saved model
model = load_model(path_saved_model, compile=True)

if source.endswith(('.jpg', '.jpeg', '.png')):
    path_to_img = source
    print('Entered1')
    # Load sample Image
    
    img = cv2.imread(path_to_img)
    print(img)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    result = pose.process(img_rgb)
    if result.pose_landmarks:
        lm_list = []
        for landmarks in result.pose_landmarks.landmark:
            # Preprocessing
            max_distance = 0
            lm_list.append(landmarks)
        print('landmarks')
        print(landmarks)
        center_x = (lm_list[landmark_names.index('right_hip')].x +
                    lm_list[landmark_names.index('left_hip')].x)*0.5
        center_y = (lm_list[landmark_names.index('right_hip')].y +
                    lm_list[landmark_names.index('left_hip')].y)*0.5

        shoulders_x = (lm_list[landmark_names.index('right_shoulder')].x +
                       lm_list[landmark_names.index('left_shoulder')].x)*0.5
        shoulders_y = (lm_list[landmark_names.index('right_shoulder')].y +
                       lm_list[landmark_names.index('left_shoulder')].y)*0.5

        for lm in lm_list:
            distance = math.sqrt((lm.x - center_x)**2 + (lm.y - center_y)**2)
            if(distance > max_distance):
                max_distance = distance
        torso_size = math.sqrt((shoulders_x - center_x) **
                               2 + (shoulders_y - center_y)**2)
        max_distance = max(torso_size*torso_size_multiplier, max_distance)

        pre_lm = list(np.array([[(landmark.x-center_x)/max_distance, (landmark.y-center_y)/max_distance,
                                 landmark.z/max_distance, landmark.visibility] for landmark in lm_list]).flatten())
        data = pd.DataFrame([pre_lm], columns=col_names)
        print(data)
        predict = model.predict(data)[0]
        print('predicted')
        if max(predict) > threshold:
            pose_class = class_names[predict.argmax()]
            print('predictions: ', predict)
            print('predicted Pose Class: ', pose_class)
        else:
            pose_class = 'Unknown Pose'
            print('[INFO] Predictions is below given Confidence!!')

    # Show Result
    img = cv2.putText(
        img, f'{class_names[predict.argmax()]}',
        (40, 50), cv2.FONT_HERSHEY_PLAIN,
        2, (255, 0, 255), 2
    )

    if save:
        os.makedirs('ImageOutput', exist_ok=True)
        img_full_name = os.path.split(path_to_img)[1]
        img_name = os.path.splitext(img_full_name)[0]
        path_to_save_img = f'ImageOutput/{img_name}.jpg'
        cv2.imwrite(f'{path_to_save_img}', img)
        print(f'[INFO] Output Image Saved in {path_to_save_img}')

    cv2.imshow('Output Image', img)
    if cv2.waitKey(0) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
    print('[INFO] Inference on Test Image is Ended...')

else:
    # Web-cam
    if source.isnumeric():
        source = int(source)

    cap = cv2.VideoCapture(source)
    source_width = int(cap.get(3))
    source_height = int(cap.get(4))

    # Write Video
    if save:
        out_video = cv2.VideoWriter('output.avi', 
                            cv2.VideoWriter_fourcc(*'MJPG'),
                            10, (source_width, source_height))

    while True:
        success, img = cap.read()
        if not success:
            print('[ERROR] Failed to Read Video feed')
            break
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        result = pose.process(img_rgb)

        if result.pose_landmarks:
            lm_list = []
            for landmarks in result.pose_landmarks.landmark:
                # Preprocessing
                max_distance = 0
                lm_list.append(landmarks)
            center_x = (lm_list[landmark_names.index('right_hip')].x +
                        lm_list[landmark_names.index('left_hip')].x)*0.5
            center_y = (lm_list[landmark_names.index('right_hip')].y +
                        lm_list[landmark_names.index('left_hip')].y)*0.5

            shoulders_x = (lm_list[landmark_names.index('right_shoulder')].x +
                           lm_list[landmark_names.index('left_shoulder')].x)*0.5

            
            shoulders_y = (lm_list[landmark_names.index('right_shoulder')].y +
                           lm_list[landmark_names.index('left_shoulder')].y)*0.5

            for lm in lm_list:
                distance = math.sqrt((lm.x - center_x) **
                                     2 + (lm.y - center_y)**2)
                if(distance > max_distance):
                    max_distance = distance
            torso_size = math.sqrt((shoulders_x - center_x) **
                                   2 + (shoulders_y - center_y)**2)
            max_distance = max(torso_size*torso_size_multiplier, max_distance)

            pre_lm = list(np.array([[(landmark.x-center_x)/max_distance, (landmark.y-center_y)/max_distance,
                                     landmark.z/max_distance, landmark.visibility] for landmark in lm_list]).flatten())
            data = pd.DataFrame([pre_lm], columns=col_names)
            # print(data[2])
            predict = model.predict(data)[0]
            if max(predict) > threshold:
                pose_class = class_names[predict.argmax()]
                print('predictions: ', predict)
                print('predicted Pose Class: ', pose_class)
            else:
                pose_class = 'Unknown Pose'
                print('[INFO] Predictions is below given Confidence!!')

            # Show Result
            img = cv2.putText(
                img, f'{pose_class}',
                (40, 50), cv2.FONT_HERSHEY_PLAIN,
                2, (255, 0, 255), 2
            )
        # Write Video
        if save:
            out_video.write(img)

        cv2.imshow('Output Image', img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    if save:
        out_video.release()
        print("[INFO] Out video Saved as 'output.avi'")
    cv2.destroyAllWindows()
    print('[INFO] Inference on Videostream is Ended...')
# Out:
# Hello
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# predictions:  [3.7867317e-03 1.4293151e-01 4.1741360e-04 8.5286433e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [3.0162075e-04 8.4601797e-02 1.8338203e-04 9.1491312e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [3.9244100e-04 6.9292318e-03 5.9696636e-06 9.9267232e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [4.0910166e-04 3.1237433e-02 1.5677213e-05 9.6833771e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [1.3043917e-02 2.2732863e-02 5.7385107e-05 9.6416581e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [2.0671706e-03 3.0933492e-02 5.0344850e-05 9.6694905e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [9.6487820e-05 5.4310807e-03 5.4250727e-06 9.9446690e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [1.0258311e-03 9.9630617e-03 3.2015440e-05 9.8897904e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [1.6401810e-04 1.2394886e-02 2.0157173e-05 9.8742098e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [6.3667598e-04 1.9660287e-03 1.5112727e-05 9.9738210e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [1.6306984e-03 1.5576417e-03 6.5386543e-05 9.9674630e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [1.4665265e-03 7.3011656e-04 3.0697982e-05 9.9777263e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [1.2526901e-03 1.1821914e-03 2.2875458e-05 9.9754226e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [8.5853518e-04 1.6859135e-03 1.9650643e-05 9.9743587e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [2.7176907e-04 3.3891370e-04 1.3465391e-06 9.9938798e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [6.5998250e-04 9.8823477e-04 2.8921008e-06 9.9834883e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [6.7492604e-04 1.5714044e-02 1.8657569e-05 9.8359239e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [1.5427910e-03 5.6772302e-03 7.5042913e-06 9.9277252e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [4.27213265e-03 1.13863535e-02 1.77484271e-05 9.84323800e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [7.8783091e-03 6.5252893e-03 2.3261178e-05 9.8557323e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [3.7409496e-03 7.2607012e-03 2.3823444e-05 9.8897457e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [1.0284770e-03 1.1463808e-02 6.5661545e-05 9.8744208e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [4.1951216e-04 5.4668281e-03 2.6288013e-05 9.9408734e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# predictions:  [4.3384098e-03 2.9242402e-02 4.6012748e-05 9.6637315e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [2.7194193e-03 8.7318690e-03 1.5290761e-05 9.8853338e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [7.6667237e-04 3.0306498e-02 2.6765032e-05 9.6890008e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [4.7360611e-04 4.4402447e-02 1.0647772e-04 9.5501745e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [2.5619550e-03 7.5491015e-03 2.8581066e-05 9.8986036e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [1.0449530e-03 1.9742193e-02 1.4701486e-05 9.7919810e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [4.7880010e-04 1.5803380e-02 1.2996962e-05 9.8370486e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predictions:  [8.5839274e-04 1.8221533e-02 1.3856993e-04 9.8078156e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [1.6620757e-04 3.6781795e-02 1.1112729e-04 9.6294081e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [5.4328982e-04 5.3228154e-03 2.8128286e-05 9.9410570e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [2.2034983e-03 1.6108883e-03 4.4707318e-05 9.9614102e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [1.4099943e-03 1.4196762e-03 4.0415220e-05 9.9712998e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [7.5613623e-03 2.6290901e-03 1.7510910e-04 9.8963445e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [4.0933979e-03 2.0875928e-03 7.0494665e-05 9.9374855e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [2.7531353e-03 1.1242399e-03 3.5048819e-05 9.9608755e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [1.9298333e-03 1.6574441e-03 2.0847161e-05 9.9639183e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [6.8457169e-04 1.0489745e-03 3.2520172e-06 9.9826318e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [3.0496417e-04 1.7969540e-03 5.7617281e-06 9.9789232e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [8.9110498e-04 3.9113816e-03 1.1309284e-05 9.9518615e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.4458896e-03 2.7791276e-03 8.9321820e-06 9.9576604e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [1.3812958e-03 5.1388545e-03 1.4205226e-05 9.9346572e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [5.5646617e-03 8.4080184e-03 3.0646934e-05 9.8599678e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [2.4234531e-03 7.6073208e-03 2.0427578e-05 9.8994875e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predictions:  [1.6407483e-03 6.7667295e-03 2.4326366e-05 9.9156827e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [1.1080698e-03 5.0319410e-03 1.0695253e-05 9.9384934e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [2.0893414e-03 8.6717363e-03 3.9325427e-05 9.8919952e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [3.4307947e-03 1.1571400e-02 3.4849480e-05 9.8496288e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [6.1708334e-04 1.1452358e-01 2.9395832e-04 8.8456529e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [4.6829329e-04 1.1055893e-01 3.8481652e-04 8.8858795e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# predictions:  [2.2205000e-03 1.1316071e-02 3.6476395e-05 9.8642701e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [3.7466376e-03 1.7404839e-02 6.2318759e-05 9.7878623e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# predictions:  [1.0598499e-03 7.9669513e-02 4.3025438e-04 9.1884035e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [4.5130684e-04 5.4804221e-02 4.3305336e-04 9.4431138e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# predictions:  [9.5685350e-04 4.2325430e-02 3.1287759e-04 9.5640475e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [1.7527629e-03 5.6862671e-02 3.9219140e-04 9.4099247e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [0.00496642 0.08872341 0.00143296 0.9048772 ]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [0.00378622 0.06538186 0.00107905 0.92975277]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [0.00369264 0.06171719 0.00100442 0.93358576]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [0.00646821 0.0692452  0.00120977 0.9230768 ]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predictions:  [4.0893550e-03 3.3419885e-02 3.7019950e-04 9.6212059e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [2.2275948e-03 1.9759625e-02 4.7017835e-04 9.7754264e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [2.7039722e-03 3.2114290e-02 5.4987927e-04 9.6463180e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predictions:  [0.0056369  0.05980982 0.00111801 0.93343526]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [6.6192406e-03 2.7263500e-02 2.0320967e-04 9.6591413e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [1.3136279e-02 2.7448803e-02 1.7219354e-04 9.5924270e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [2.0371182e-02 2.2763167e-02 1.5379257e-04 9.5671195e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [1.2110413e-02 2.6212137e-02 1.9086168e-04 9.6148658e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [4.1812756e-03 3.7958324e-02 2.9334790e-04 9.5756704e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [4.7775889e-03 3.0841028e-02 1.7787975e-04 9.6420348e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [5.7073846e-03 2.3209780e-02 1.4025092e-04 9.7094256e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [6.8254657e-03 2.1600733e-02 1.4022151e-04 9.7143352e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [7.7357581e-03 1.9508846e-02 1.3006218e-04 9.7262537e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [1.3337214e-02 1.2753588e-02 1.1116868e-04 9.7379792e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# predictions:  [1.0103055e-02 2.1403356e-02 1.2673187e-04 9.6836692e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [7.4293390e-03 2.3776332e-02 1.2193041e-04 9.6867239e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [4.8646405e-03 1.8973466e-02 6.3751977e-05 9.7609818e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [3.86107154e-03 2.32255291e-02 1.05371146e-04 9.72808003e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [4.4195075e-03 1.1133224e-02 5.0999708e-05 9.8439622e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [4.4924049e-03 7.4012163e-03 3.8165199e-05 9.8806816e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [5.87902451e-03 1.05967615e-02 5.95740712e-05 9.83464599e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [6.0855299e-03 1.1612671e-02 6.4186010e-05 9.8223764e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [6.7241285e-03 1.2322774e-02 7.1388356e-05 9.8088169e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [9.6413102e-03 1.8173175e-02 1.3677029e-04 9.7204876e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.31446365e-02 2.31929440e-02 2.18038447e-04 9.63444352e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.5130793e-02 5.1963318e-02 5.0559326e-04 9.3240035e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [1.3797905e-02 6.2140748e-02 4.3951222e-04 9.2362183e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [1.2982564e-02 5.7738818e-02 2.9133237e-04 9.2898732e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [1.2173248e-02 5.7276294e-02 2.2095269e-04 9.3032950e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [0.01771688 0.09931119 0.00105154 0.8819203 ]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [1.7378025e-02 7.1736112e-02 6.9843617e-04 9.1018748e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [0.02339957 0.11620983 0.00159214 0.8587985 ]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [1.3332102e-02 7.4678846e-02 4.1279208e-04 9.1157621e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [1.0317816e-02 5.2439764e-02 2.1295968e-04 9.3702942e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [9.8199965e-03 3.5070591e-02 1.3906081e-04 9.5497030e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [1.1402453e-02 4.2742871e-02 2.0283613e-04 9.4565183e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [1.26351025e-02 3.93858701e-02 2.04805910e-04 9.47774291e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.1860116e-02 3.6028594e-02 1.7137223e-04 9.5193994e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [1.1964109e-02 3.8962744e-02 1.9715783e-04 9.4887596e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [1.2650142e-02 2.9099001e-02 1.4739620e-04 9.5810348e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [1.4175919e-02 3.1702619e-02 1.6437734e-04 9.5395708e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [1.3689177e-02 3.1713888e-02 1.7100536e-04 9.5442593e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [1.3953865e-02 2.7444433e-02 1.3423100e-04 9.5846736e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [1.5358725e-02 2.3971016e-02 1.2753853e-04 9.6054262e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [1.2420230e-02 2.2395127e-02 1.2265788e-04 9.6506196e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [9.6858758e-03 1.7083211e-02 9.6258984e-05 9.7313458e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [8.76293331e-03 1.79050528e-02 1.04282306e-04 9.73227739e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [7.5124972e-03 1.4155473e-02 8.3425592e-05 9.7824860e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [7.2513325e-03 1.3049429e-02 7.7618402e-05 9.7962153e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [4.7076363e-03 1.1052855e-02 6.3815947e-05 9.8417574e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [5.7149036e-03 1.2413114e-02 7.0529924e-05 9.8180145e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [7.9267435e-03 1.3969414e-02 7.5630080e-05 9.7802812e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [9.0279579e-03 1.2512754e-02 6.9172107e-05 9.7839010e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [8.8558290e-03 1.1424902e-02 6.5698965e-05 9.7965348e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predictions:  [9.8601878e-03 1.2761995e-02 7.5192445e-05 9.7730255e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [9.3516922e-03 1.3252709e-02 7.7500903e-05 9.7731805e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [7.2316416e-03 1.0757556e-02 6.5270397e-05 9.8194557e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [8.4936284e-03 1.3961336e-02 9.5624477e-05 9.7744948e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [5.2778609e-03 1.7554270e-02 1.0441421e-04 9.7706336e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [8.3615324e-03 1.8708147e-02 1.0417687e-04 9.7282618e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [5.4986500e-03 1.4529253e-02 8.4554100e-05 9.7988749e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [4.1818824e-03 8.3414493e-03 4.1068957e-05 9.8743558e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [3.6090508e-03 8.4200967e-03 4.0556024e-05 9.8793030e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [3.2909345e-03 8.9316685e-03 3.8885151e-05 9.8773861e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [5.31173917e-03 1.20950835e-02 5.20788490e-05 9.82541144e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [7.3220697e-03 1.0651593e-02 5.8532329e-05 9.8196775e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [5.2109486e-03 1.8001098e-02 1.0206948e-04 9.7668582e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [6.1400253e-03 1.9167207e-02 1.1827649e-04 9.7457451e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [5.8133481e-03 2.8939921e-02 1.5891591e-04 9.6508783e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [1.0850481e-02 2.7009323e-02 1.4757905e-04 9.6199268e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [1.1181002e-02 2.1838812e-02 1.3659040e-04 9.6684355e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [1.3876647e-02 3.7125736e-02 2.2324550e-04 9.4877440e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [1.3074852e-02 3.4854192e-02 2.0028153e-04 9.5187056e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [9.63493716e-03 2.02263761e-02 1.20317774e-04 9.70018446e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [8.8178888e-03 1.9909441e-02 1.1852100e-04 9.7115415e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [1.2871825e-02 2.7430501e-02 1.8306045e-04 9.5951456e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [1.6137799e-02 3.2105807e-02 2.1103825e-04 9.5154524e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [1.3969498e-02 3.0603418e-02 1.8631386e-04 9.5524073e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.7963344e-02 4.3020230e-02 3.3075531e-04 9.3868572e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predictions:  [2.0865846e-02 4.9613781e-02 3.1602633e-04 9.2920434e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [2.1025199e-02 4.9802475e-02 2.9775963e-04 9.2887461e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# predictions:  [2.0583268e-02 5.7776019e-02 3.0790889e-04 9.2133278e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.9210426e-02 6.4478301e-02 3.2246171e-04 9.1598880e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.8277602e-02 5.7676680e-02 3.1171236e-04 9.2373401e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [1.8205125e-02 4.8959915e-02 3.4895621e-04 9.3248606e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [1.1161580e-02 3.8065095e-02 2.3863777e-04 9.5053464e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [8.8894349e-03 3.9732911e-02 2.4719074e-04 9.5113045e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [9.5963161e-03 3.4878381e-02 2.4177786e-04 9.5528346e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [7.4120499e-03 2.2279311e-02 1.5234748e-04 9.7015619e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [4.3717124e-03 1.1310012e-02 7.6625038e-05 9.8424166e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [6.5158266e-03 2.0804333e-02 1.4518801e-04 9.7253460e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [7.8460760e-03 2.4230046e-02 2.0001204e-04 9.6772391e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [1.0173804e-02 3.2906912e-02 4.1300975e-04 9.5650631e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.5599616e-02 3.9357040e-02 6.2047294e-04 9.4442290e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [0.02538479 0.07367582 0.00234413 0.8985953 ]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predictions:  [1.2195516e-02 2.2552088e-02 2.2413538e-04 9.6502829e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [5.7854238e-03 2.2252580e-02 1.3555177e-04 9.7182637e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [4.1319286e-03 1.8958736e-02 9.9532532e-05 9.7680980e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [4.51261317e-03 2.05220655e-02 1.13902126e-04 9.74851429e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [3.1899547e-03 1.5567742e-02 9.3557508e-05 9.8114878e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [2.9591422e-03 1.2868726e-02 7.5028329e-05 9.8409712e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [2.7317370e-03 1.2211737e-02 5.9846505e-05 9.8499668e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [4.7742114e-03 2.1853864e-02 1.2632286e-04 9.7324556e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [3.9481479e-03 2.0968318e-02 9.5990363e-05 9.7498757e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [7.9735732e-03 3.0779587e-02 2.0210544e-04 9.6104479e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [9.0267472e-03 4.3464396e-02 2.4127714e-04 9.4726753e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [1.0847162e-02 5.4136474e-02 3.6322267e-04 9.3465322e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [1.1264425e-02 5.3289711e-02 3.1952793e-04 9.3512625e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [8.8759391e-03 3.9999925e-02 1.9335852e-04 9.5093077e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [8.4950635e-03 4.2200953e-02 2.3265545e-04 9.4907135e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [1.0974333e-02 5.6231178e-02 4.2946334e-04 9.3236506e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [7.6761055e-03 3.0881656e-02 1.9788052e-04 9.6124429e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [6.8954444e-03 2.6057292e-02 1.5664696e-04 9.6689063e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# predictions:  [6.3978280e-03 2.6712732e-02 1.6091618e-04 9.6672851e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [5.0933175e-03 2.5653981e-02 1.4211050e-04 9.6911049e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [5.32168383e-03 2.27510389e-02 1.14334915e-04 9.71812963e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [4.1078799e-03 1.5955446e-02 7.5766606e-05 9.7986090e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# predictions:  [5.90905594e-03 1.28466552e-02 1.02601065e-04 9.81141627e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [5.97777683e-03 1.17365904e-02 1.14369956e-04 9.82171297e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [9.3227066e-03 1.7798113e-02 1.8342370e-04 9.7269577e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [6.5174936e-03 1.3056461e-02 1.5937998e-04 9.8026675e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [5.6843879e-03 9.6180709e-03 1.1796905e-04 9.8457956e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [7.9072686e-03 2.2351237e-02 5.0223130e-04 9.6923929e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [1.8603135e-03 6.0382034e-03 8.3766652e-05 9.9201775e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [4.9528712e-03 1.1907285e-02 1.4821201e-04 9.8299164e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [5.0472608e-03 9.2558656e-03 1.1332340e-04 9.8558354e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [2.9779898e-03 8.9964727e-03 8.0504324e-05 9.8794496e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [3.5138219e-03 1.0194404e-02 9.7774318e-05 9.8619407e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# predictions:  [3.5837770e-03 1.1527864e-02 8.8583860e-05 9.8479986e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [6.0390555e-03 1.2771263e-02 1.3778849e-04 9.8105192e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [6.5023028e-03 1.3416930e-02 1.4281797e-04 9.7993785e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [7.4733519e-03 2.4421124e-02 1.6986550e-04 9.6793562e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [7.8871157e-03 2.5410593e-02 1.9267859e-04 9.6650958e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [5.8577466e-03 1.4886378e-02 8.9548557e-05 9.7916633e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [6.0524698e-03 1.0108776e-02 7.4389405e-05 9.8376435e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [5.1637539e-03 6.6533992e-03 6.6295106e-05 9.8811662e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [4.7535379e-03 7.7770967e-03 8.8708162e-05 9.8738062e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [4.3573445e-03 1.3466717e-02 1.6133698e-04 9.8201454e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [3.1699948e-03 1.0928814e-02 7.2828916e-05 9.8582840e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [3.2922931e-03 1.0287085e-02 6.3576583e-05 9.8635709e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [3.7016345e-03 1.2787474e-02 7.5184907e-05 9.8343569e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [4.0806709e-03 1.2060911e-02 7.0058180e-05 9.8378837e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# predictions:  [6.2676407e-03 1.1090029e-02 8.7340493e-05 9.8255491e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [1.1390812e-02 1.3998742e-02 1.7265513e-04 9.7443783e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [9.6146893e-03 1.4301875e-02 1.3821168e-04 9.7594517e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [7.17232935e-03 1.07646305e-02 8.05727104e-05 9.81982470e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [6.2323608e-03 1.3855127e-02 8.0544451e-05 9.7983187e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [6.5827179e-03 1.7174026e-02 9.5312629e-05 9.7614801e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [6.3023590e-03 1.7864639e-02 9.0708032e-05 9.7574234e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [5.8287489e-03 1.8713022e-02 8.9503497e-05 9.7536874e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [5.4233787e-03 1.5761409e-02 7.6605887e-05 9.7873873e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [5.1337630e-03 1.3579143e-02 6.7231915e-05 9.8121989e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [5.5399295e-03 1.3462727e-02 7.6662312e-05 9.8092067e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [4.3927561e-03 1.3555563e-02 7.2109484e-05 9.8197961e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [4.7756191e-03 1.5414916e-02 7.7109733e-05 9.7973228e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [4.0721977e-03 1.5072228e-02 7.6607386e-05 9.8077893e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [3.6259010e-03 1.3335318e-02 7.4615265e-05 9.8296422e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [3.4276599e-03 1.3685617e-02 7.6855387e-05 9.8280990e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [4.1738702e-03 1.0050173e-02 6.7714231e-05 9.8570824e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [5.8779237e-03 1.0269094e-02 8.1465019e-05 9.8377150e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [5.1357988e-03 9.9468241e-03 5.9684917e-05 9.8485768e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [4.807457e-03 1.530433e-02 7.529133e-05 9.798130e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [5.1252842e-03 1.9065967e-02 8.8362933e-05 9.7572029e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [3.5591384e-03 1.4451082e-02 6.7110384e-05 9.8192275e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [2.5576334e-03 1.1554463e-02 6.3114137e-05 9.8582470e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [2.9923434e-03 1.3752045e-02 7.8400750e-05 9.8317724e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [4.6867202e-03 1.0680628e-02 9.8956763e-05 9.8453367e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [3.7324473e-03 9.1740284e-03 8.2519779e-05 9.8701108e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [3.8237902e-03 8.5848235e-03 7.4723437e-05 9.8751664e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [3.1162424e-03 7.4682874e-03 4.7848571e-05 9.8936754e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [3.5349499e-03 9.3527157e-03 4.8350383e-05 9.8706400e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [4.3516522e-03 8.2792602e-03 5.1379964e-05 9.8731762e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [4.7691129e-03 8.5256966e-03 5.6362918e-05 9.8664874e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [6.01660833e-03 1.18224565e-02 1.00090198e-04 9.82060790e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [5.5233403e-03 1.2269045e-02 9.4500232e-05 9.8211306e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [6.730894e-03 1.338399e-02 1.453390e-04 9.797397e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [6.1987811e-03 1.2153749e-02 1.1799826e-04 9.8152941e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [5.7280711e-03 9.4550848e-03 8.4387735e-05 9.8473245e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [9.8700123e-03 2.9175712e-02 2.7947617e-04 9.6067482e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [6.4953202e-03 2.5941504e-02 1.6600489e-04 9.6739721e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [5.9823077e-03 1.8150227e-02 1.5786631e-04 9.7570950e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [3.70356720e-03 1.40562905e-02 9.14912453e-05 9.82148647e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predictions:  [3.6935559e-03 1.4971533e-02 9.0375615e-05 9.8124450e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [4.1949037e-03 1.5756017e-02 1.0247072e-04 9.7994655e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [3.3403195e-03 1.2315749e-02 5.8747111e-05 9.8428518e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [2.3975314e-03 1.3879163e-02 7.0944472e-05 9.8365235e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [3.6778385e-03 1.3144281e-02 7.7419034e-05 9.8310041e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [3.5762403e-03 1.3549388e-02 6.6317582e-05 9.8280805e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [3.8402816e-03 1.3772231e-02 6.2575738e-05 9.8232484e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [3.6268285e-03 1.3769256e-02 6.9722882e-05 9.8253423e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [3.1732519e-03 1.1425631e-02 5.5581197e-05 9.8534554e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [2.978106e-03 9.615860e-03 4.798855e-05 9.873581e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [3.1561479e-03 1.2952127e-02 5.8940939e-05 9.8383278e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [3.1942637e-03 1.6038487e-02 6.8856898e-05 9.8069829e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [5.5758101e-03 2.0427009e-02 1.2064065e-04 9.7387654e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [6.6136708e-03 2.6546741e-02 1.3398305e-04 9.6670556e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [5.02920151e-03 2.53829788e-02 1.08124485e-04 9.69479680e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [5.1127230e-03 2.3175273e-02 9.6877811e-05 9.7161508e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [3.4466553e-03 1.7686205e-02 7.1842544e-05 9.7879523e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [3.9135935e-03 1.7783571e-02 8.7256638e-05 9.7821552e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [3.3679993e-03 1.2041071e-02 6.6862907e-05 9.8452395e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [3.3364824e-03 9.6680550e-03 6.5350636e-05 9.8693001e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# predictions:  [4.6176952e-03 1.8047379e-02 1.5842305e-04 9.7717655e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# predictions:  [4.9439333e-03 2.1009726e-02 1.2132764e-04 9.7392499e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# predictions:  [6.7167459e-03 3.3653341e-02 3.2781652e-04 9.5930213e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# predictions:  [6.4988988e-03 2.1188140e-02 1.7295462e-04 9.7213989e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [3.6795670e-03 1.4656953e-02 1.4326689e-04 9.8152024e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [2.5888328e-03 6.8577179e-03 4.3474854e-05 9.9050993e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predictions:  [5.0025308e-03 7.3665199e-03 5.0475308e-05 9.8758042e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [3.6578889e-03 5.5501023e-03 3.7508878e-05 9.9075449e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# predictions:  [4.6415417e-03 7.3548113e-03 5.4880122e-05 9.8794878e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [9.2809647e-03 1.1261425e-02 9.5914300e-05 9.7936171e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [8.8545932e-03 1.1936307e-02 8.7046064e-05 9.7912210e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [9.6490337e-03 1.3503439e-02 1.4513252e-04 9.7670245e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# predictions:  [0.01576466 0.05017502 0.00102472 0.93303555]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [3.187730e-02 5.973882e-02 6.919852e-04 9.076919e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [6.383361e-03 9.984504e-03 4.649471e-05 9.835856e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [7.8163724e-03 1.1922791e-02 6.2093924e-05 9.8019880e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [7.3256493e-03 1.2869132e-02 7.6310818e-05 9.7972888e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [6.3540572e-03 1.1354989e-02 6.5199732e-05 9.8222578e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [5.8634491e-03 1.1124335e-02 6.0183571e-05 9.8295206e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [5.5105290e-03 1.0481788e-02 5.6199289e-05 9.8395145e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [3.8526685e-03 1.2148890e-02 5.9856327e-05 9.8393863e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [4.2957547e-03 1.2646617e-02 6.2035899e-05 9.8299557e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# predictions:  [7.4818553e-03 2.3101615e-02 1.2903086e-04 9.6928746e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [4.9843220e-03 2.2105264e-02 1.0697061e-04 9.7280347e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [3.2826432e-03 1.8279610e-02 8.5425410e-05 9.7835231e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [2.9673907e-03 1.3451130e-02 5.6047498e-05 9.8352551e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [2.6296570e-03 1.2684244e-02 5.0416795e-05 9.8463571e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# predictions:  [2.9311276e-03 1.3615125e-02 6.4015287e-05 9.8338979e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predictions:  [3.8904885e-03 1.6183453e-02 7.6920827e-05 9.7984916e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [6.2396335e-03 1.5023442e-02 8.3111212e-05 9.7865373e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [6.9313329e-03 1.3264614e-02 9.4697498e-05 9.7970939e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [6.6821547e-03 1.1555116e-02 8.1768369e-05 9.8168093e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [7.6482780e-03 2.5767650e-02 2.0552859e-04 9.6637851e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [5.3839865e-03 1.9213425e-02 1.6711802e-04 9.7523540e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [5.5585192e-03 1.1361017e-02 9.2019538e-05 9.8298854e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [4.7758766e-03 1.6059196e-02 1.2187047e-04 9.7904301e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predictions:  [3.0233369e-03 1.6974568e-02 1.0506956e-04 9.7989708e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [2.2951835e-03 1.5800055e-02 1.3110747e-04 9.8177367e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# predictions:  [2.0591600e-03 1.5432822e-02 1.2685222e-04 9.8238117e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [1.9073316e-03 1.2498998e-02 1.0234525e-04 9.8549128e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# predictions:  [1.7116899e-03 1.4029760e-02 2.1887534e-04 9.8403972e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# predictions:  [2.4776037e-03 1.1557738e-02 1.8628665e-04 9.8577833e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# predictions:  [1.4834850e-03 6.7481534e-03 4.9301918e-05 9.9171913e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [4.25880961e-03 8.93966481e-03 1.06998275e-04 9.86694455e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [3.7556791e-03 9.3802698e-03 9.0154055e-05 9.8677385e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [5.0934991e-03 1.5642393e-02 1.5243422e-04 9.7911167e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [4.6115099e-03 1.5822547e-02 1.3396365e-04 9.7943205e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [3.8470658e-03 2.6561935e-02 3.1721097e-04 9.6927375e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [2.8357627e-03 1.5138330e-02 7.1789575e-05 9.8195410e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predictions:  [3.1272550e-03 1.5448966e-02 7.0282258e-05 9.8135340e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predictions:  [3.4647253e-03 1.8097920e-02 8.3485036e-05 9.7835392e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [2.0342290e-03 1.8931881e-02 8.4489504e-05 9.7894943e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# predictions:  [2.6277793e-03 1.9878827e-02 1.1586020e-04 9.7737759e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [2.9699998e-03 2.2093059e-02 1.4139109e-04 9.7479558e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# predictions:  [3.9602569e-03 2.6918326e-02 2.3052703e-04 9.6889091e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# predictions:  [3.661536e-03 2.280156e-02 2.074858e-04 9.733295e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [3.4375438e-03 2.1316363e-02 1.9954859e-04 9.7504652e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [3.9072940e-03 1.7638791e-02 1.0921094e-04 9.7834468e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [4.03133919e-03 1.79724786e-02 1.18151496e-04 9.77877975e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [4.8043360e-03 1.5817527e-02 7.8388366e-05 9.7929972e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [5.4057185e-03 1.7273124e-02 8.9372741e-05 9.7723186e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# predictions:  [5.4950011e-03 1.7031869e-02 8.4480955e-05 9.7738862e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predictions:  [5.9437202e-03 2.1926722e-02 1.0463031e-04 9.7202504e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predictions:  [6.0858717e-03 1.0995310e-02 5.2914031e-05 9.8286587e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [6.6983216e-03 1.0105160e-02 7.7201177e-05 9.8311931e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [8.3783828e-03 2.0203907e-02 1.9478056e-04 9.7122294e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [8.1987986e-03 2.0385182e-02 1.8687572e-04 9.7122914e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions:  [7.4102012e-03 1.8699432e-02 1.4746173e-04 9.7374290e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predictions:  [7.0450939e-03 1.7549984e-02 1.1793357e-04 9.7528708e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# predictions:  [5.7235528e-03 1.6407825e-02 8.7259941e-05 9.7778147e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# predictions:  [5.1602251e-03 1.4873663e-02 6.6952351e-05 9.7989917e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predictions:  [4.3416796e-03 9.9331727e-03 5.7059471e-05 9.8566806e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [5.5261827e-03 8.2568461e-03 5.2241758e-05 9.8616469e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predictions:  [4.8597571e-03 7.1718893e-03 4.0807470e-05 9.8792762e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predictions:  [3.4198018e-03 7.5406535e-03 3.6063167e-05 9.8900348e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [4.8378999e-03 1.0581482e-02 4.6214616e-05 9.8453438e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predictions:  [6.6836458e-03 1.7079035e-02 7.2450232e-05 9.7616482e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# predictions:  [4.2885672e-03 1.6898224e-02 5.9408590e-05 9.7875381e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# predictions:  [4.3381057e-03 2.7235536e-02 1.2701207e-04 9.6829939e-01]
# predicted Pose Class:  Waving
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# predictions:  [4.8789755e-03 2.6741717e-02 1.3226342e-04 9.6824706e-01]
# predicted Pose Class:  Waving
# [INFO] Out video Saved as 'output.avi'
# [INFO] Inference on Videostream is Ended...

# %% [markdown]
# ## C. Intrusion Detection code

# %%
# Import the required libraries
import numpy as np
import cv2
import time
import datetime
from collections import deque
from twilio.rest import Client 
import random
import heapq
import os
import matplotlib.pyplot as plt
import random
import requests


print("Libraries succesfully imported")
# Out:
# Libraries succesfully imported

# %%
def is_person_present(frame, thresh=1100):
    kernel = None
    global foog
    
    # Apply background subtraction
    fgmask = foog.apply(frame)

    # Get rid of the shadows
    ret, fgmask = cv2.threshold(fgmask, 250, 255, cv2.THRESH_BINARY)

    # Apply some morphological operations to make sure you have a good mask
    fgmask = cv2.dilate(fgmask, kernel, iterations=4)

    # Detect contours in the frame
    contours, hierarchy = cv2.findContours(fgmask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
     
    # Check if there was a contour and the area is somewhat higher than some threshold so we know it's a person and not noise
    if contours and cv2.contourArea(max(contours, key=cv2.contourArea)) > thresh:
            
        # Get the max contour
        cnt = max(contours, key=cv2.contourArea)

        # Draw a bounding box around the person and label it as person detected
        x, y, w, h = cv2.boundingRect(cnt)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)
        cv2.putText(frame, 'Person Detected', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0, 255, 0), 1, cv2.LINE_AA)
        
        return True, frame
        
        
    # Otherwise report there was no one present
    else:
        return False, frame


def send_message(body, info_dict):

    # Your Account SID from twilio.com/console
    account_sid = info_dict['account_sid']

    # Your Auth Token from twilio.com/console
    auth_token  = info_dict['auth_token']


    client = Client(account_sid, auth_token)

    message = client.messages.create(to=info_dict['your_num'], from_=info_dict['trial_num'], body=body)





def calculate_percentage_change(frame1, frame2):
    # Convert frames to grayscale
    gray_frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray_frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

    # Calculate absolute difference between the two frames
    abs_diff = cv2.absdiff(gray_frame1, gray_frame2)

    # Calculate percentage change
    percentage_change = (np.count_nonzero(abs_diff) / abs_diff.size) * 100

    return percentage_change


def save_frame(frame_heap): 
    frame_index = 0
    while frame_heap:
        # Pop the frame with the maximum percentage change (negated)
        neg_change_percentage, frame , date = heapq.heappop(frame_heap)
        change_percentage = -neg_change_percentage
        file_path = 'DetectedPerson'
        # Save the frame to disk
        cv2.imwrite(f'{file_path}/{date}.jpg', frame)
        frame_index += 1
    print("saved frame succesfully")


    


print('no error in functions')
# Out:
# no error in functions

# %% [markdown]
# ## Final Code

# %%
# Set Window normal so we can resize it
cv2.namedWindow('frame', cv2.WINDOW_NORMAL)

# This is a test video
cap = cv2.VideoCapture('sample_video1.mp4')

# Read the video stream from the camera
# cap = cv2.VideoCapture('http://192.168.43.1:8080/video')

# Get width and height of the frame
width = int(cap.get(3))
height = int(cap.get(4))

# Read and store the credentials information in a dict
with open('credential.txt', 'r') as myfile:
  data = myfile.read()

info_dict = eval(data)

# Initialize the background Subtractor
foog = cv2.createBackgroundSubtractorMOG2(detectShadows=True, varThreshold=100, history=2000)

# Status is True when person is present and False when the person is not present.
status = False

# After the person disappears from view, wait at least 7 seconds before making the status False
patience = 0.099

# We don't consider an initial detection unless it's detected 15 times, this gets rid of false positives
detection_thresh = 5

# Initial time for calculating if patience time is up
initial_time = None



# We are creating a deque object of length detection_thresh and will store individual detection statuses here
de = deque([False] * 10, maxlen=10)

# Initialize an empty heap to store frames along with their negated percentage change
frame_heap = []


# Initialize these variables for calculating FPS
fps = 0 
frame_counter = 0
start_time = time.time()
counter = 0

ret,prevframe = cap.read()
initial_frame = prevframe
recognisedName = ""
sent  = False

while True:
    
    ret, frame = cap.read()
    if not ret:
        break 
    
            
    # This function will return a boolean variable telling if someone was present or not, it will also draw boxes if it 
    # finds someone
    detected, annotated_image = is_person_present(frame)  
    # print(recognisedName)
    if detected and len(recognisedName) == 0: 
        # result = recogniseFromFace(frame)  
        result = ''
        if result is not None: 
            result = ''
    # Register the current detection status on our deque object
    de.appendleft(detected)
    
    # If we have consecutively detected a person 15 times then we are sure that someone is present    
    # We also make this is the first time that this person has been detected so we only initialize the videowriter once
    if sum(de) == detection_thresh and not status:                       
            status = True
            entry_time = datetime.datetime.now().strftime("%A, %I-%M-%S %p %d %B %Y")
            # out = cv2.VideoWriter('outputs/{}.mp4'.format(entry_time), cv2.VideoWriter_fourcc(*'XVID'), 15.0, (width, height))

    # If status is True but the person is not in the current frame
    if status and not detected:
        
        # Restart the patience timer only if the person has not been detected for a few frames so we are sure it wasn't a 
        # False positive
        print('i reached deepest of the darkest point')
        if sum(de) > (detection_thresh/2): 
            if initial_time is None:
                print('initial time as been setted to',initial_time)
                initial_time = time.time()
                
            
            elif initial_time is not None:        
                print('now the initial time is not null beacuse current time is ',initial_time)
                print(time.time() - initial_time)
                # If the patience has run out and the person is still not detected then set the status to False
                # Also save the video by releasing the video writer and send a text message.
                if  time.time() - initial_time >= patience:
                    status = False
                    print("inside the loop")
                    exit_time = datetime.datetime.now().strftime("%A, %I:%M:%S %p %d %B %Y")
                    # out.release()
                    # print(out)
                    initial_time = None
                    de = deque([False] * len(de))
                    body = "Alert: \nA Person Entered the Room at {} \nLeft the room at {}".format(entry_time, exit_time) 
                    if len(recognisedName) > 0: 
                        body = "Alert: {} Has entered in your Room at {} \n Left the room at {}".format(recognisedName,entry_time,exit_time)
                    print('message has been sent')
                    send_message(body, info_dict)
                    frame_index = 0
                    cv2.destroyWindow("frame")
                    while frame_heap:
                        # Pop the frame with the maximum percentage change (negated)
                        neg_change_percentage, frame , date = heapq.heappop(frame_heap)
                        change_percentage = -neg_change_percentage
                        file_path = 'DetectedPerson'
                        
                        # Save the frame to disk
                        cv2.imwrite(f'{file_path}/{date}.jpg', frame)
                        frame_index += 1
                    print("saved frame succesfully")
                    continue
                    
                
    
    # If a significant amount of detections (more than half of detection_thresh) has occurred then we reset the Initial Time.
    elif status and sum(de) > (detection_thresh/2):
        change_percentage = calculate_percentage_change(prevframe, frame)
        change_initial_change = calculate_percentage_change(initial_frame,frame)
        # print(change_percentage)
        if change_percentage > 95 and sent == False: 
            sent = True
            body = "Alert: \n Some one has changed the camera configuration at:{}".format(datetime.datetime.now().strftime("%A, %I-%M-%S %p %d %B %Y")) 
            send_message(body,info_dict)
    
        if change_initial_change > 60: 
            heapq.heappush(frame_heap, (-change_percentage, frame,datetime.datetime.now().strftime("%A, %I-%M-%S %p %d %B %Y")))
        prevframe = frame
        initial_time = None
    
    # Get the current time in the required format
    current_time = datetime.datetime.now().strftime("%A, %I:%M:%S %p %d %B %Y")

    # Display the FPS
    cv2.putText(annotated_image, 'FPS: {:.2f}'.format(fps), (510, 450), cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 40, 155), 2)
    
    # Display Time
    cv2.putText(annotated_image, current_time, (310, 20), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 255), 1)    
    
    # Display the Room Status
    cv2.putText(annotated_image, 'Room Occupied: {}'.format(str(status)), (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.6, 
                (200, 10, 150), 2)

    # Show the patience Value
    if initial_time is None:
        text = 'Patience: {}'.format(patience)
    else: 
        text = 'Patience: {:.2f}'.format(max(0, patience - (time.time() - initial_time)))
        
    cv2.putText(annotated_image, text, (10, 450), cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 40, 155), 2)   

 
    # Show the Frame
    cv2.imshow('frame', frame)
    
    # Calculate the Average FPS
    frame_counter += 1
    fps = (frame_counter / (time.time() - start_time))
    
    
    # Exit if q is pressed.
    if cv2.waitKey(30) == ord('q'):
        break


# Release Capture and destroy windows
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## D. Final Code Of ML

# %%
import pickle
from collections import Counter
import keras
import numpy as np
import cv2
import time
import datetime
from collections import deque
from twilio.rest import Client 
import random
import heapq
import os
import matplotlib.pyplot as plt
import random
import requests
import keras
from keras import layers, Sequential
from keras.models import load_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import mediapipe as mp
import glob
import pandas as pd
import math




print("Libraries succesfully imported") 

mp1 = keras.models.load_model("Models/FaceRecognitionModel.keras")


path_saved_model = "Models/Action Recognition/model.keras"
threshold = 0.2
save = "Output"
print('Hello')
##############
torso_size_multiplier = 2.5
n_landmarks = 33
n_dimensions = 3
landmark_names = [
    'nose',
    'left_eye_inner', 'left_eye', 'left_eye_outer',
    'right_eye_inner', 'right_eye', 'right_eye_outer',
    'left_ear', 'right_ear',
    'mouth_left', 'mouth_right',
    'left_shoulder', 'right_shoulder',
    'left_elbow', 'right_elbow',
    'left_wrist', 'right_wrist',
    'left_pinky_1', 'right_pinky_1',
    'left_index_1', 'right_index_1',
    'left_thumb_2', 'right_thumb_2',
    'left_hip', 'right_hip',
    'left_knee', 'right_knee',
    'left_ankle', 'right_ankle',
    'left_heel', 'right_heel',
    'left_foot_index', 'right_foot_index',
]
class_names = [
    'Running','Standing','Walking','Waving'
]


mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

col_names = []
for i in range(n_landmarks):
    name = mp_pose.PoseLandmark(i).name
    name_x = name + '_X'
    name_y = name + '_Y'
    name_z = name + '_Z'
    name_v = name + '_V'
    col_names.append(name_x)
    col_names.append(name_y)
    col_names.append(name_z)
    col_names.append(name_v)

# Load saved model
model = load_model(path_saved_model, compile=True)


# Load the face classifier
face_classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# Load the face map for label mapping
with open("ResultsMap.pkl", 'rb') as fileReadStream:
    ResultMap = pickle.load(fileReadStream)

print(ResultMap)

recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read("Models/ModelToRecogniseUnrecogniseFace.yml")


# Function to recognize faces
def recognize_faces(frame):
    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    predicted_label = ''
    for (x, y, w, h) in faces:
        # Extract the face ROI
        face_roi = frame[y:y+h, x:x+w]
        face_roi1 = gray[y:y+h, x:x+w]

        # Resize the face ROI to match the input size of the model
        label_id, confidence = recognizer.predict(face_roi1)

        # Resize the face ROI to match the input size of the model
        resized_face = cv2.resize(face_roi, (64, 64))

        # Preprocess the face (normalize pixel values)
        normalized_face = resized_face / 255.0

        # Reshape the face for the model input (add batch dimension)
        reshaped_face = np.expand_dims(normalized_face, axis=0)

        # Perform prediction using the model
        prediction = mp1.predict(reshaped_face)
        predicted_label = ResultMap[np.argmax(prediction)]
        print('confidence',prediction[0][np.argmax(prediction)])
        print(prediction)
        # print(predicted_label)
        print(np.max(prediction))
        name = predicted_label
        pre = np.max(prediction)
        print(confidence)
        if confidence > 70: 
            cv2.putText(frame, 'Unknown', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2) 
            name = 'Unknown'
        else:
            cv2.putText(frame, predicted_label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)

        print(name)
        # Draw the bounding box and label on the frame
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
    return predicted_label , frame


def recognisize_pose(frame): 
    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = pose.process(img_rgb)
    activity = ''
    if result.pose_landmarks:
        lm_list = []
        for landmarks in result.pose_landmarks.landmark:
            # Preprocessing
            max_distance = 0
            lm_list.append(landmarks)
        # print('landmarks')
        # print(landmarks)
        center_x = (lm_list[landmark_names.index('right_hip')].x +
                    lm_list[landmark_names.index('left_hip')].x)*0.5
        center_y = (lm_list[landmark_names.index('right_hip')].y +
                    lm_list[landmark_names.index('left_hip')].y)*0.5

        shoulders_x = (lm_list[landmark_names.index('right_shoulder')].x +
                       lm_list[landmark_names.index('left_shoulder')].x)*0.5
        shoulders_y = (lm_list[landmark_names.index('right_shoulder')].y +
                       lm_list[landmark_names.index('left_shoulder')].y)*0.5

        for lm in lm_list:
            distance = math.sqrt((lm.x - center_x)**2 + (lm.y - center_y)**2)
            if(distance > max_distance):
                max_distance = distance
        torso_size = math.sqrt((shoulders_x - center_x) **
                               2 + (shoulders_y - center_y)**2)
        max_distance = max(torso_size*torso_size_multiplier, max_distance)

        pre_lm = list(np.array([[(landmark.x-center_x)/max_distance, (landmark.y-center_y)/max_distance,
                                 landmark.z/max_distance, landmark.visibility] for landmark in lm_list]).flatten())
        data = pd.DataFrame([pre_lm], columns=col_names)
        # print(data)
        predict = model.predict(data)[0]
        print('predicted')
        activity = class_names[predict.argmax()]
        if max(predict) > threshold:
            pose_class = class_names[predict.argmax()]
            print('predictions: ', predict)
            print('predicted Pose Class: ', pose_class)
        else:
            pose_class = 'Unknown Pose'
            print('[INFO] Predictions is below given Confidence!!')

        frame = cv2.putText(
                frame, f'{class_names[predict.argmax()]}',
                (40, 50), cv2.FONT_HERSHEY_PLAIN,
                2, (255, 0, 255), 2
        )
    
    print('[INFO] Inference on Test Image is Ended...')
    return activity 



def is_person_present(frame, thresh=1100):
    kernel = None
    global foog
    
    # Apply background subtraction
    fgmask = foog.apply(frame)

    # Get rid of the shadows
    ret, fgmask = cv2.threshold(fgmask, 250, 255, cv2.THRESH_BINARY)

    # Apply some morphological operations to make sure you have a good mask
    fgmask = cv2.dilate(fgmask, kernel, iterations=4)

    # Detect contours in the frame
    contours, hierarchy = cv2.findContours(fgmask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
     
    # Check if there was a contour and the area is somewhat higher than some threshold so we know it's a person and not noise
    if contours and cv2.contourArea(max(contours, key=cv2.contourArea)) > thresh:
            
        # Get the max contour
        cnt = max(contours, key=cv2.contourArea)

        # Draw a bounding box around the person and label it as person detected
        x, y, w, h = cv2.boundingRect(cnt)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)
        cv2.putText(frame, 'Person Detected', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0, 255, 0), 1, cv2.LINE_AA)
        
        return True, frame
        
        
    # Otherwise report there was no one present
    else:
        return False, frame


def send_message(body, info_dict):

    # Your Account SID from twilio.com/console
    account_sid = info_dict['account_sid']

    # Your Auth Token from twilio.com/console
    auth_token  = info_dict['auth_token']


    client = Client(account_sid, auth_token)

    message = client.messages.create(to=info_dict['your_num'], from_=info_dict['trial_num'], body=body)





def calculate_percentage_change(frame1, frame2):
    # Convert frames to grayscale
    gray_frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray_frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

    # Calculate absolute difference between the two frames
    abs_diff = cv2.absdiff(gray_frame1, gray_frame2)

    # Calculate percentage change
    percentage_change = (np.count_nonzero(abs_diff) / abs_diff.size) * 100

    return percentage_change


def save_frame(frame_heap): 
    frame_index = 0
    while frame_heap:
        # Pop the frame with the maximum percentage change (negated)
        neg_change_percentage, frame , date = heapq.heappop(frame_heap)
        change_percentage = -neg_change_percentage
        file_path = 'DetectedPerson'
        # Save the frame to disk
        cv2.imwrite(f'{file_path}/{date}.jpg', frame)
        frame_index += 1
    print("saved frame succesfully")

print('no error in functions')
# Out:
# Libraries succesfully imported
# Hello
# {0: 'Pushkar', 1: 'Sairaj', 2: 'Tushar'}
# no error in functions

# %%
# Set Window normal so we can resize it
cv2.namedWindow('frame', cv2.WINDOW_NORMAL)

# This is a test video
# cap = cv2.VideoCapture("sample_video1.mp4")

# Read the video stream from the camera
cap = cv2.VideoCapture('http://192.168.43.1:8080/video')

# Get width and height of the frame
width = int(cap.get(3))
height = int(cap.get(4))

# Read and store the credentials information in a dict
with open('credential.txt', 'r') as myfile:
  data = myfile.read()

info_dict = eval(data)

# Initialize the background Subtractor
foog = cv2.createBackgroundSubtractorMOG2(detectShadows=True, varThreshold=100, history=2000)

# Status is True when person is present and False when the person is not present.
status = False

# After the person disappears from view, wait at least 7 seconds before making the status False
patience = 0.099

# We don't consider an initial detection unless it's detected 15 times, this gets rid of false positives
detection_thresh = 5

# Initial time for calculating if patience time is up
initial_time = None



# We are creating a deque object of length detection_thresh and will store individual detection statuses here
de = deque([False] * 10, maxlen=10)

# Initialize an empty heap to store frames along with their negated percentage change
frame_heap = []


# Initialize these variables for calculating FPS
fps = 0 
frame_counter = 0
start_time = time.time()
counter = 0

ret,prevframe = cap.read()
initial_frame = prevframe
recognisedName = ""
sent  = False
activity = []

while True:
    
    ret, frame = cap.read()
    if not ret:
        break 
    
    print(recognisedName)
    # This function will return a boolean variable telling if someone was present or not, it will also draw boxes if it 
    # finds someone
    detected, annotated_image = is_person_present(frame)  
    # print(recognisedName)
    # print('Hello')
    

    if detected and len(recognisedName) == 0: 
        # result = recogniseFromFace(frame)  
        print('inside block')
        result = recognize_faces(frame)  
        # print(result)
        activties = recognisize_pose(frame)
        # print(activties)
        activity.append(activties) 
        name , frame = result
        print('inside block')
        if name is not None: 
            if name: 
                recognisedName = name 
            else: 
                recognisedName = ""
    # Register the current detection status on our deque object
    de.appendleft(detected)
    
    # If we have consecutively detected a person 15 times then we are sure that someone is present    
    # We also make this is the first time that this person has been detected so we only initialize the videowriter once
    if sum(de) == detection_thresh and not status:                       
            status = True
            entry_time = datetime.datetime.now().strftime("%A, %I-%M-%S %p %d %B %Y")
            # out = cv2.VideoWriter('outputs/{}.mp4'.format(entry_time), cv2.VideoWriter_fourcc(*'XVID'), 15.0, (width, height))

    # If status is True but the person is not in the current frame
    if status and not detected:
        
        # Restart the patience timer only if the person has not been detected for a few frames so we are sure it wasn't a 
        # False positive
        print('i reached deepest of the darkest point')
        if sum(de) > (detection_thresh/2): 
            if initial_time is None:
                print('initial time as been setted to',initial_time)
                initial_time = time.time()
                
            
            elif initial_time is not None:        
                print('now the initial time is not null beacuse current time is ',initial_time)
                print(time.time() - initial_time)
                # If the patience has run out and the person is still not detected then set the status to False
                # Also save the video by releasing the video writer and send a text message.
                if  time.time() - initial_time >= patience:
                    status = False
                    print("inside the loop")
                    exit_time = datetime.datetime.now().strftime("%A, %I:%M:%S %p %d %B %Y")
                    # out.release()
                    # print(out)
                    initial_time = None
                    de = deque([False] * len(de))
                    element_counts = Counter(activity)
                    
                    # Find the most common element
                    most_common_element = element_counts.most_common(1)
                    if most_common_element:
                        most_common_element = most_common_element[0][0]
                        # Do something with most_common_element
                    else:
                        # Handle the case when there are no elements
                        most_common_element = 'unknown activites'
                    body = "Alert: \nA Person Entered the Room at {} \nLeft the room at {} and did ".format(entry_time, exit_time,most_common_element) 
                    # Use Counter to count occurrences of each element
                    activity.clear()
                    if len(recognisedName) > 0: 
                        body = "Alert: {} Has entered in your Room at {} \n Left the room at {} and did {}".format(recognisedName,entry_time,exit_time, most_common_element)
                    print('message has been sent')
                    send_message(body, info_dict)
                    frame_index = 0
                    cv2.destroyWindow("frame")
                    while frame_heap:
                        # Pop the frame with the maximum percentage change (negated)
                        neg_change_percentage, frame , date = heapq.heappop(frame_heap)
                        change_percentage = -neg_change_percentage
                        file_path = 'DetectedPerson'
                        
                        # Save the frame to disk
                        cv2.imwrite(f'{file_path}/{date}.jpg', frame)
                        frame_index += 1
                    print("saved frame succesfully")
                    recognisedName = "" 
                    activity = []
                    continue
                    
                
    
    # If a significant amount of detections (more than half of detection_thresh) has occurred then we reset the Initial Time.
    elif status and sum(de) > (detection_thresh/2):
        change_percentage = calculate_percentage_change(prevframe, frame)
        change_initial_change = calculate_percentage_change(initial_frame,frame)
        # print(change_percentage)
        if change_percentage > 95 and sent == False: 
            sent = True
            body = "Alert: \n Some one has changed the camera configuration at:{}".format(datetime.datetime.now().strftime("%A, %I-%M-%S %p %d %B %Y")) 
            if recognisedName != 'Unknown': 
                body = "Alert: \n {} has changed the camera configuration at:{}".format(recognisedName, datetime.datetime.now().strftime("%A, %I-%M-%S %p %d %B %Y")) 
            send_message(body,info_dict)
    
        if change_initial_change > 60: 
            heapq.heappush(frame_heap, (-change_percentage, frame,datetime.datetime.now().strftime("%A, %I-%M-%S %p %d %B %Y")))
        prevframe = frame
        initial_time = None
    
    # Get the current time in the required format
    current_time = datetime.datetime.now().strftime("%A, %I:%M:%S %p %d %B %Y")

    # Display the FPS
    cv2.putText(annotated_image, 'FPS: {:.2f}'.format(fps), (510, 450), cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 40, 155), 2)
    
    # Display Time
    cv2.putText(annotated_image, current_time, (310, 20), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 0, 255), 1)    
    
    # Display the Room Status
    cv2.putText(annotated_image, 'Room Occupied: {}'.format(str(status)), (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.6, 
                (200, 10, 150), 2)

    # Show the patience Value
    if initial_time is None:
        text = 'Patience: {}'.format(patience)
    else: 
        text = 'Patience: {:.2f}'.format(max(0, patience - (time.time() - initial_time)))
        
    cv2.putText(annotated_image, text, (10, 450), cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 40, 155), 2)   

 
    # Show the Frame
    cv2.imshow('frame', frame)
    
    # Calculate the Average FPS
    frame_counter += 1
    fps = (frame_counter / (time.time() - start_time))
    
    
    # Exit if q is pressed.
    if cv2.waitKey(30) == ord('q'):
        break


# Release Capture and destroy windows
cap.release()
cv2.destroyAllWindows()

while frame_heap:
    # Pop the frame with the maximum percentage change (negated)
    neg_change_percentage, frame , date = heapq.heappop(frame_heap)
    change_percentage = -neg_change_percentage
    file_path = 'DetectedPerson'
                        
    # Save the frame to disk
    cv2.imwrite(f'{file_path}/{date}.jpg', frame)
    frame_index += 1
    print("saved frame succesfully")
# Out:
# inside block
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
#
#
#
#
# inside block
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# predicted
# predictions:  [0.08939882 0.86259836 0.02882284 0.01917993]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predicted
# predictions:  [0.22426225 0.6911128  0.04584526 0.03877966]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predicted
# predictions:  [0.09881219 0.85404944 0.03410117 0.01303716]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predicted
# predictions:  [0.02628325 0.94940805 0.01638214 0.00792656]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# predicted
# predictions:  [0.03164544 0.941232   0.01745842 0.00966411]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predicted
# predictions:  [0.00484339 0.98568904 0.00749849 0.00196917]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predicted
# predictions:  [0.01141437 0.97165686 0.0122493  0.00467938]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# confidence 0.3380075
# [[0.3325498  0.3380075  0.32944268]]
# 0.3380075
# 161.76180032570923
# Unknown
# [INFO] Inference on Test Image is Ended...
# inside block
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# Sairaj
# i reached deepest of the darkest point
# initial time as been setted to None
# Sairaj
# i reached deepest of the darkest point
# now the initial time is not null beacuse current time is  1713216953.4614325
# 0.11229562759399414
# inside the loop
# message has been sent
# saved frame succesfully
#
#
#
#
#
#
#
#
#
#
#
# inside block
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predicted
# predictions:  [0.02237724 0.92775524 0.03158735 0.01828015]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predicted
# predictions:  [0.07785777 0.73962784 0.04700666 0.13550775]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# predicted
# predictions:  [0.08164532 0.5873477  0.03599219 0.29501483]
# predicted Pose Class:  Standing
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# predicted
# predictions:  [2.2714025e-01 2.6155743e-01 5.1084602e-01 4.5626613e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# predicted
# predictions:  [0.40655732 0.2847821  0.30820692 0.00045365]
# predicted Pose Class:  Running
# [INFO] Inference on Test Image is Ended...
# inside block
#
# i reached deepest of the darkest point
# initial time as been setted to None
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# predicted
# predictions:  [0.3870945  0.2631666  0.34932414 0.00041476]
# predicted Pose Class:  Running
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# predicted
# predictions:  [5.6084764e-01 2.5145057e-01 1.8735783e-01 3.4402241e-04]
# predicted Pose Class:  Running
# [INFO] Inference on Test Image is Ended...
# inside block
#
# i reached deepest of the darkest point
# initial time as been setted to None
#
# i reached deepest of the darkest point
# now the initial time is not null beacuse current time is  1713216964.0562708
# 0.10176539421081543
# inside the loop
# message has been sent
# saved frame succesfully
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# predicted
# predictions:  [3.6220962e-01 1.0689893e-01 5.3049725e-01 3.9412099e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# predicted
# predictions:  [3.0879763e-01 1.3258497e-01 5.5825269e-01 3.6469122e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# predicted
# predictions:  [2.9396427e-01 1.0103705e-01 6.0466099e-01 3.3776130e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
#
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# predicted
# predictions:  [3.4266007e-01 1.0249388e-01 5.5456561e-01 2.8040202e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# predicted
# predictions:  [3.2553491e-01 1.4883935e-01 5.2529526e-01 3.3043922e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# predicted
# predictions:  [2.9948953e-01 1.6082910e-01 5.3938699e-01 2.9440047e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# predicted
# predictions:  [3.8695478e-01 1.1275561e-01 4.9989083e-01 3.9880772e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# i reached deepest of the darkest point
# initial time as been setted to None
#
# i reached deepest of the darkest point
# now the initial time is not null beacuse current time is  1713216978.9349673
# 0.15827512741088867
# inside the loop
# message has been sent
# saved frame succesfully
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# predicted
# predictions:  [3.5056576e-01 6.7933299e-02 5.8113497e-01 3.6592194e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# predicted
# predictions:  [3.1368354e-01 5.9430946e-02 6.2650448e-01 3.8104691e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# predicted
# predictions:  [4.2695290e-01 5.3318977e-02 5.1934665e-01 3.8150948e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# predicted
# predictions:  [4.1818708e-01 6.1575200e-02 5.1987273e-01 3.6502499e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# predicted
# predictions:  [4.8814264e-01 9.5058091e-02 4.1641334e-01 3.8593923e-04]
# predicted Pose Class:  Running
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# predicted
# predictions:  [4.7022483e-01 8.8501632e-02 4.4088033e-01 3.9322409e-04]
# predicted Pose Class:  Running
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predicted
# predictions:  [2.7507094e-01 1.0802787e-01 6.1656296e-01 3.3819335e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predicted
# predictions:  [3.1149849e-01 1.0720128e-01 5.8095419e-01 3.4602548e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# predicted
# predictions:  [3.2659614e-01 1.0429131e-01 5.6868088e-01 4.3158987e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# predicted
# predictions:  [4.5623183e-01 8.4550776e-02 4.5877755e-01 4.3987000e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# predicted
# predictions:  [4.1673312e-01 8.0105461e-02 5.0275248e-01 4.0886737e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# predicted
# predictions:  [3.3452162e-01 7.0573218e-02 5.9454018e-01 3.6497656e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# predicted
# predictions:  [2.8884515e-01 5.5508092e-02 6.5529412e-01 3.5263103e-04]
# predicted Pose Class:  Walking
# [INFO] Inference on Test Image is Ended...
# inside block
#
# inside block
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# predicted
# predictions:  [5.0032699e-01 1.3870122e-01 3.6063802e-01 3.3381212e-04]
# predicted Pose Class:  Running
# [INFO] Inference on Test Image is Ended...
# inside block
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully
# saved frame succesfully

# %%
mp.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)                   │ (None, 60, 60, 32)          │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_18 (MaxPooling2D)      │ (None, 30, 30, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 26, 26, 64)          │          51,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_19 (MaxPooling2D)      │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_9 (Flatten)                  │ (None, 10816)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 64)                  │         692,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,238,539 (8.54 MB)
#  Trainable params: 746,179 (2.85 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,492,360 (5.69 MB)
